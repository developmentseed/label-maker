# %%
# %%file mx_lenet_sagemaker.py
import logging
from os import path as op
import os

import mxnet as mx
import numpy as np

data_path = os.getcwd()+ "/"
batch_size = 50
num_cpus = 0
num_gpus = 1

def prep_data(data_path):
    """
    Convert numpy array to mx Nd-array.
    Parameters
    ----------
    path: the directory that save data.npz.
    """
    data = np.load(find_file(data_path, 'data.npz'))
    x_train = data['x_train']
    y_train = data['y_train'][:,:1] ## only take the second column of y_train
    x_test = data['x_test']
    y_test = data['y_test'][:,:1]
    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')

    img_mean = np.mean(x_train, axis=(0, 1, 2))
    img_std = np.std(x_train, axis=(0, 1, 2))
    
    x_train -= img_mean
    x_train /= img_std
    x_test -= img_mean
    x_test /= img_std

    img_rows = 256
    img_cols = 256

    x_train = x_train.reshape(x_train.shape[0], 3, img_rows, img_cols) ## reshape it to (448, ) instead of (448,1)
    x_test = x_test.reshape(x_test.shape[0], 3, img_rows, img_cols)
    y_train = y_train.reshape(y_train.shape[0], )
    y_test = y_test.reshape(y_test.shape[0], )
    print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)

    train_iter = mx.io.NDArrayIter(x_train, y_train, batch_size, shuffle=True)
    val_iter = mx.io.NDArrayIter(x_test, y_test, batch_size)

    return train_iter, val_iter

def find_file(root_path, file_name):
    """
    Searching for data.npz at its root director, and return a full path for the file.
    Parameters
    ----------
    root_path: the root directory for data.npz.
    file_name: refers to data.npz
    """
    for root, dirs, files in os.walk(root_path):
        if file_name in files:
            return os.path.join(root, file_name)

def mx_lenet():
    """Building a three layer LeNet sytle Convolutional Neural Net using MXNet."""
    data = mx.sym.var('data')
    data_dp = mx.symbol.Dropout(data, p = 0.2) ## 20% of the input that gets dropped out during training time
    # first conv layer
    conv1 = mx.sym.Convolution(data=data_dp, kernel=(5, 5), num_filter=20)
    tanh1 = mx.sym.Activation(data=conv1, act_type="tanh")
    pool1 = mx.sym.Pooling(data=tanh1, pool_type="max", kernel=(2, 2), stride=(2, 2))
    # second conv layer
    conv2 = mx.sym.Convolution(data=pool1, kernel=(5, 5), num_filter=50)
    tanh2 = mx.sym.Activation(data=conv2, act_type="tanh")
    pool2 = mx.sym.Pooling(data=tanh2, pool_type="max", kernel=(2, 2), stride=(2, 2))
    
    # third conv layer
    conv3 = mx.sym.Convolution(data=pool1, kernel=(5, 5), num_filter=50)
    tanh3 = mx.sym.Activation(data=conv2, act_type="tanh")
    pool3 = mx.sym.Pooling(data=tanh2, pool_type="max", kernel=(2, 2), stride=(2, 2))
    
    # first fullc layer
    flatten = mx.sym.flatten(data=pool3)
    fc1 = mx.symbol.FullyConnected(data=flatten, num_hidden=500)
    tanh4 = mx.sym.Activation(data=fc1, act_type="tanh")
    # second fullc
    fc2 = mx.sym.FullyConnected(data=tanh4, num_hidden=2)
    # softmax loss
    return mx.sym.SoftmaxOutput(data=fc2, name='softmax')


def train(num_cpus, num_gpus, **kwargs):
    """
    Train the image classification neural net.
    Parameters
    ----------
    num_cpus: If train the model on an aws GPS machine, num_cpus = 0 and num_gpus = 1, vice versa.
    num_gpus: apply to the same rule above
    """
    train_iter, val_iter = prep_data(data_path)
    lenet = mx_lenet()
    lenet_model = mx.mod.Module(
        symbol=lenet,
        context=get_train_context(num_cpus, num_gpus))
    logging.getLogger().setLevel(logging.DEBUG)
    lenet_model.fit(train_iter,
                    eval_data=val_iter,
                    optimizer='sgd',
                    optimizer_params={'learning_rate': 0.1},
                    eval_metric='acc',
                    batch_end_callback=mx.callback.Speedometer(batch_size, 16),
                    num_epoch=100)
    return lenet_model


def get_train_context(num_cpus, num_gpus):
    """
    Define the model training instance.
    Parameters
    ----------
    num_cpus: If train the model on an aws GPS machine, num_cpus = 0 and num_gpus = 1, vice versa.
    num_gpus: apply to the same rule above
    """
    if num_gpus > 0:
        return mx.gpu()
    return mx.cpu()

def get_train_context(num_cpus, num_gpus):
    if num_gpus > 0:
        print("It's {} instance".format(num_gpus))
        return mx.gpu()
    print("It's {} instance".format(num_cpus))
    return mx.cpu()
# Out:
# Overwriting mx_lenet_sagemaker.py

# %%
# %%time
from sagemaker.mxnet import MXNet
from sagemaker import get_execution_role

mxnet_estimator = MXNet("mx_lenet_sagemaker.py", 
                        role=get_execution_role(), 
                        train_instance_type="ml.p2.xlarge", 
                        train_instance_count=1)
mxnet_estimator.fit("s3://") ## give your s3 bucket URL here.
# Out:
# INFO:sagemaker:Created S3 bucket: sagemaker-us-east-1-552819999234
# INFO:sagemaker:Creating training-job with name: sagemaker-mxnet-py2-gpu-2018-01-13-17-41-10-313
# ..................................................................................
# executing startup script (first run)
# 2018-01-13 17:47:55,321 INFO - root - running container entrypoint
# 2018-01-13 17:47:55,321 INFO - root - starting train task
# 2018-01-13 17:47:56,932 INFO - mxnet_container.train - MXNetTrainingEnvironment: {'enable_cloudwatch_metrics': False, 'available_gpus': 1, 'channels': {u'training': {u'TrainingInputMode': u'File', u'RecordWrapperType': u'None', u'S3DistributionType': u'FullyReplicated'}}, '_ps_verbose': 0, 'resource_config': {u'current_host': u'algo-1', u'hosts': [u'algo-1']}, 'user_script_name': u'mx_lenet_sagemaker.py', 'input_config_dir': '/opt/ml/input/config', 'channel_dirs': {u'training': u'/opt/ml/input/data/training'}, 'code_dir': '/opt/ml/code', 'output_data_dir': '/opt/ml/output/data/', 'output_dir': '/opt/ml/output', 'model_dir': '/opt/ml/model', 'hyperparameters': {u'sagemaker_program': u'mx_lenet_sagemaker.py', u'sagemaker_submit_directory': u's3://sagemaker-us-east-1-552819999234/sagemaker-mxnet-py2-gpu-2018-01-13-17-41-10-313/source/sourcedir.tar.gz', u'sagemaker_region': u'us-east-1', u'sagemaker_enable_cloudwatch_metrics': False, u'sagemaker_job_name': u'sagemaker-mxnet-py2-gpu-2018-01-13-17-41-10-313', u'sagemaker_container_log_level': 20}, 'hosts': [u'algo-1'], '_ps_port': 8000, 'user_script_archive': u's3://sagemaker-us-east-1-552819999234/sagemaker-mxnet-py2-gpu-2018-01-13-17-41-10-313/source/sourcedir.tar.gz', 'sagemaker_region': u'us-east-1', 'input_dir': '/opt/ml/input', 'current_host': u'algo-1', 'container_log_level': 20, 'available_cpus': 4, 'base_dir': '/opt/ml'}
# Downloading s3://sagemaker-us-east-1-552819999234/sagemaker-mxnet-py2-gpu-2018-01-13-17-41-10-313/source/sourcedir.tar.gz to /tmp/script.tar.gz
# 2018-01-13 17:47:57,048 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTP connection (1): 169.254.170.2
# 2018-01-13 17:47:57,167 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTPS connection (1): s3.amazonaws.com
# ((1831, 3, 256, 256), (458, 3, 256, 256), (1831,), (458,))
# It's 1 instance
# [17:48:16] src/operator/././cudnn_algoreg-inl.h:106: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# 2018-01-13 17:48:22,757 INFO - root - Epoch[0] Batch [16]#011Speed: 267.66 samples/sec#011accuracy=0.577647
# 2018-01-13 17:48:25,755 INFO - root - Epoch[0] Batch [32]#011Speed: 266.91 samples/sec#011accuracy=0.518750
# 2018-01-13 17:48:26,506 INFO - root - Epoch[0] Train-accuracy=0.475000
# 2018-01-13 17:48:26,506 INFO - root - Epoch[0] Time cost=8.286
# 2018-01-13 17:48:28,533 INFO - root - Epoch[0] Validation-accuracy=0.550000
# 2018-01-13 17:48:31,590 INFO - root - Epoch[1] Batch [16]#011Speed: 267.80 samples/sec#011accuracy=0.591765
# 2018-01-13 17:48:34,586 INFO - root - Epoch[1] Batch [32]#011Speed: 267.07 samples/sec#011accuracy=0.480000
# 2018-01-13 17:48:35,340 INFO - root - Epoch[1] Train-accuracy=0.520000
# 2018-01-13 17:48:35,340 INFO - root - Epoch[1] Time cost=6.807
# 2018-01-13 17:48:37,389 INFO - root - Epoch[1] Validation-accuracy=0.474000
# 2018-01-13 17:48:40,438 INFO - root - Epoch[2] Batch [16]#011Speed: 268.43 samples/sec#011accuracy=0.487059
# 2018-01-13 17:48:43,435 INFO - root - Epoch[2] Batch [32]#011Speed: 266.98 samples/sec#011accuracy=0.537500
# 2018-01-13 17:48:44,186 INFO - root - Epoch[2] Train-accuracy=0.480000
# 2018-01-13 17:48:44,186 INFO - root - Epoch[2] Time cost=6.797
# 2018-01-13 17:48:46,227 INFO - root - Epoch[2] Validation-accuracy=0.522000
# 2018-01-13 17:48:49,286 INFO - root - Epoch[3] Batch [16]#011Speed: 267.61 samples/sec#011accuracy=0.507059
# 2018-01-13 17:48:52,289 INFO - root - Epoch[3] Batch [32]#011Speed: 266.43 samples/sec#011accuracy=0.480000
# 2018-01-13 17:48:53,035 INFO - root - Epoch[3] Train-accuracy=0.520000
# 2018-01-13 17:48:53,035 INFO - root - Epoch[3] Time cost=6.808
# 2018-01-13 17:48:55,070 INFO - root - Epoch[3] Validation-accuracy=0.476000
# 2018-01-13 17:48:58,127 INFO - root - Epoch[4] Batch [16]#011Speed: 267.81 samples/sec#011accuracy=0.503529
# 2018-01-13 17:49:01,135 INFO - root - Epoch[4] Batch [32]#011Speed: 265.94 samples/sec#011accuracy=0.483750
# 2018-01-13 17:49:01,887 INFO - root - Epoch[4] Train-accuracy=0.520000
# 2018-01-13 17:49:01,888 INFO - root - Epoch[4] Time cost=6.818
# 2018-01-13 17:49:03,922 INFO - root - Epoch[4] Validation-accuracy=0.474000
# 2018-01-13 17:49:06,979 INFO - root - Epoch[5] Batch [16]#011Speed: 267.80 samples/sec#011accuracy=0.494118
# 2018-01-13 18:00:09,248 INFO - root - Epoch[79] Time cost=6.816
# 2018-01-13 18:00:11,294 INFO - root - Epoch[79] Validation-accuracy=0.656000
# 2018-01-13 18:00:14,354 INFO - root - Epoch[80] Batch [16]#011Speed: 267.69 samples/sec#011accuracy=0.708235
# 2018-01-13 18:00:17,364 INFO - root - Epoch[80] Batch [32]#011Speed: 265.82 samples/sec#011accuracy=0.746250
# 2018-01-13 18:00:18,121 INFO - root - Epoch[80] Train-accuracy=0.795000
# 2018-01-13 18:00:18,121 INFO - root - Epoch[80] Time cost=6.827
# 2018-01-13 18:00:20,159 INFO - root - Epoch[80] Validation-accuracy=0.600000
# 2018-01-13 18:00:23,227 INFO - root - Epoch[81] Batch [16]#011Speed: 266.95 samples/sec#011accuracy=0.692941
# 2018-01-13 18:00:26,242 INFO - root - Epoch[81] Batch [32]#011Speed: 265.36 samples/sec#011accuracy=0.698750
# 2018-01-13 18:00:26,995 INFO - root - Epoch[81] Train-accuracy=0.795000
# 2018-01-13 18:00:26,995 INFO - root - Epoch[81] Time cost=6.836
# 2018-01-13 18:00:29,041 INFO - root - Epoch[81] Validation-accuracy=0.682000
# 2018-01-13 18:00:32,118 INFO - root - Epoch[82] Batch [16]#011Speed: 266.30 samples/sec#011accuracy=0.737647
# 2018-01-13 18:00:35,139 INFO - root - Epoch[82] Batch [32]#011Speed: 264.88 samples/sec#011accuracy=0.733750
# 2018-01-13 18:00:35,892 INFO - root - Epoch[82] Train-accuracy=0.650000
# 2018-01-13 18:00:35,892 INFO - root - Epoch[82] Time cost=6.851
# 2018-01-13 18:00:37,936 INFO - root - Epoch[82] Validation-accuracy=0.676000
# 2018-01-13 18:00:41,013 INFO - root - Epoch[83] Batch [16]#011Speed: 266.05 samples/sec#011accuracy=0.736471
# 2018-01-13 18:00:44,041 INFO - root - Epoch[83] Batch [32]#011Speed: 264.19 samples/sec#011accuracy=0.715000
# 2018-01-13 18:00:44,801 INFO - root - Epoch[83] Train-accuracy=0.690000
# 2018-01-13 18:00:44,801 INFO - root - Epoch[83] Time cost=6.865
# 2018-01-13 18:00:46,853 INFO - root - Epoch[83] Validation-accuracy=0.654000
# 2018-01-13 18:00:49,941 INFO - root - Epoch[84] Batch [16]#011Speed: 265.27 samples/sec#011accuracy=0.680000
# 2018-01-13 18:00:52,973 INFO - root - Epoch[84] Batch [32]#011Speed: 263.85 samples/sec#011accuracy=0.661250
# 2018-01-13 18:00:53,733 INFO - root - Epoch[84] Train-accuracy=0.740000
# 2018-01-13 18:00:53,733 INFO - root - Epoch[84] Time cost=6.880
# 2018-01-13 18:00:55,772 INFO - root - Epoch[84] Validation-accuracy=0.688000
# 2018-01-13 18:00:58,858 INFO - root - Epoch[85] Batch [16]#011Speed: 265.41 samples/sec#011accuracy=0.738824
# 2018-01-13 18:01:01,895 INFO - root - Epoch[85] Batch [32]#011Speed: 263.49 samples/sec#011accuracy=0.713750
# 2018-01-13 18:01:02,656 INFO - root - Epoch[85] Train-accuracy=0.790000
# 2018-01-13 18:01:02,657 INFO - root - Epoch[85] Time cost=6.884
# 2018-01-13 18:02:57,378 INFO - root - Epoch[98] Batch [32]#011Speed: 264.56 samples/sec#011accuracy=0.738750
# 2018-01-13 18:02:58,136 INFO - root - Epoch[98] Train-accuracy=0.715000
# 2018-01-13 18:02:58,136 INFO - root - Epoch[98] Time cost=6.863
# 2018-01-13 18:03:00,181 INFO - root - Epoch[98] Validation-accuracy=0.646000
# 2018-01-13 18:03:03,264 INFO - root - Epoch[99] Batch [16]#011Speed: 265.68 samples/sec#011accuracy=0.730588
# 2018-01-13 18:03:06,299 INFO - root - Epoch[99] Batch [32]#011Speed: 263.61 samples/sec#011accuracy=0.707500
# 2018-01-13 18:03:07,059 INFO - root - Epoch[99] Train-accuracy=0.755000
# 2018-01-13 18:03:07,060 INFO - root - Epoch[99] Time cost=6.878
# 2018-01-13 18:03:09,126 INFO - root - Epoch[99] Validation-accuracy=0.672000
# ===== Job Complete =====
# CPU times: user 1.85 s, sys: 384 ms, total: 2.24 s
# Wall time: 23min 21s

# %%
# %%time
predictor = mxnet_estimator.deploy(initial_instance_count=1,
                                   instance_type='ml.p2.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-mxnet-py2-gpu-2018-01-13-17-41-10-313
# INFO:sagemaker:Creating endpoint with name sagemaker-mxnet-py2-gpu-2018-01-13-17-41-10-313
# -------------------------------------------------------------------------------------------------------------------------------------------------------------!CPU times: user 560 ms, sys: 44 ms, total: 604 ms
# Wall time: 13min 20s

# %%
import numpy as np
import boto3
import botocore
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline


def pred_img(bucket, img_s3, img_nn, image_mean, image_std):
    s3 = boto3.resource('s3')

    try:
        s3.Bucket(bucket).download_file(img_s3, img_nn)
        print("{} download under current directory".format(img_s3))
    except botocore.exceptions.ClientError as e:
        if e.response['Error']['Code'] == "404":
            print("The object does not exist.")
        else:
            raise
    img=Image.open(img_nn)
    img_np = np.array(img).astype('float32')
    # RBG chanels are between 0-255, so rescale it to be between 0-1.
    img_np /=255
    img_np -= image_mean
    img_np /= image_std
    #reshape the image to (1, 3, 256, 256) to pass to the predictor of MXNet Estimator
    img_np = img_np.reshape(1,img_np.shape[2],img_np.shape[0], img_np.shape[1]) 
    pred = predictor.predict(img_np)
    return pred

# %%
# replace with your bucket name
bucket = ''
# full path to the test image
img_s3 = 'MXNnet_example/data/103922-57564-17.jpg' 
# the new given name for the image you wanna save in current work directory
img_nn = "Image_1.jpg"

"""
Image mean and image_std are obtained from data.npz's by 
running img_mean = np.mean(x_train, axis=(0, 1, 2)), img_std = np.std(x_train, axis=(0, 1, 2))
"""
image_mean = np.array([ 0.14663778,  0.1624524 , -0.21313858]).astype('float32')
image_std = np.array([ 0.86569798,  0.77569193,  0.79192579]).astype('float32')

# %%
pred = pred_img(bucket, img_s3, img_nn, image_mean, image_std)
image_1 = plt.imread("Image_1.jpg")
plt.imshow(image_1)
print("The overall prediction is: {}".format(pred))
for item in pred:
    if item[0] > item[1]:
        print("It's background tile")
    else:
        print("The tile cantain building(s)!")
# Out:
# MX-Net/data/103922-57564-17.jpg download under current directory
# The overall prediction is: [[5.465806793836236e-07, 0.9999994039535522]]
# The tile cantain building(s)!
